# %% [markdown]
# # Training launcher
# This is a test for a launcher notebook to be used on Colab.
# The first cells should retrieve the drive and repository paths to get datasets and code.
# The third cell launches the training function of the network.

# %% [markdown]
# ## Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Clone the GitHub repository

# %%
# Clone the repository
# !git clone https://github.com/morgmatt/DLNN_lab.git

# Move to the correct folder
# %cd DLNN_lab/5-conv-autoencoders/project-attempt

# %% [markdown]
# ## Launch the network training

# %%
# Execute the train.py file in /src
# !python src/train.py --epochs 15 --batch_size 128 --save_dir "/content/drive/MyDrive/DLNN/5-Autoencoder/run_01"
