# %% [markdown]
# # Inception-v4 launcher

# %%
# Mount the drive
from google.colab import drive
drive.mount('/content/drive')

# !git clone https://github.com/morgmatt/DLNN_lab.git

# Move to the correct folder
# %cd DLNN_lab/4-resnet-inception/Inception-v4

# %%
# TensorBoard loader
# %load_ext tensorboard
# %tensorboard --logdir /content/drive/MyDrive/DLNN/4-ResNet-50/checkpoints/tensorboard_logs

# %%
# Execute the train.py file in /src
# !python src/train.py --epochs 15 --batch_size 128 --data_dir "/content/drive/MyDrive/DLNN/4-Inception-v4/dataset" --save_dir "/content/drive/MyDrive/DLNN/4-Inception-v4/run_01"

# %%
# Execute the train.py file in /src
# !python src/evaluation.py --batch_size 128 --data_dir "/content/drive/MyDrive/DLNN/4-Inception-v4/dataset" --model_path "/content/drive/MyDrive/DLNN/4-Inception-v4/run_01" --save_dir "/content/drive/MyDrive/DLNN/4-Inception-v4/results"
